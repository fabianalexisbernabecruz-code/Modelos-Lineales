# %% [markdown]
# <font face="Times New Roman">
#
#  <img src = "https://upload.wikimedia.org/wikipedia/commons/c/ca/Escudo-UNAM-escalable.svg" width="150" height="170" align="left"/>
#
#   <img src = "https://upload.wikimedia.org/wikipedia/commons/5/5b/Escudo-facultad-ciencias-unam-escalable.svg" width="150" height="170" align="right"/>
#
# <font face="Times New Roman">
# <h5 align="center"><i></i></h5>
# <h1 align="center" style><b> TAREA 1</b></h1>
# </font>
# <font face="Times New Roman">
#
# ---
# ---
#
# <h5 align="center"><i>MODELOS LINEALES</i></h5>
#
# ---
# ---
#
# <font face="Times New Roman">
#
#
#
# <h5 align="center"><i>Semestre 2026-2</i></h5>
# <h5 align="center"><i>Grupo: 9286</i></h5>
#
#
# ---
# ---
#
# <font color="Black" face="Times New Roman">
# <h5 align="center"><i>Profesor: Ricardo Ramírez Aldana</i></h5>
# <h5 align="center"><i> Ayudante: Fidel Roberto Castellanos Duran
# <h5 align="center"><i> Ayudante: Juan Pablo Rodríguez Villagrán
#
#
# </i></h5>
#
# <font color="Black" face="Times New Roman">
#
# ---
# ---
# <h5 align="center" style><b> Equipo B </i></h5>
#
#
# <h5 align="center"><i>Bernabe Cruz Fabian Alexis </i></h5>
#
# <h5 align="center"><i>Malfavón Sánchez Salvador </i></h5>
#
# <h5 align="center"><i> Martínez Gregorio Johanna </i></h5>
#
# <h5 align="center"><i>Vázquez Jiménez Arlett Paola </i></h5>
#
#
#
#
#
#
# ---
# ---

# %% [markdown]
# <font face="Times New Roman">
#
# # Librerías

# %%
install.packages("car")
library(haven)
library(readr)
library(ggplot2)
library(car)
library(lmtest)
library(MASS)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# <font face="Times New Roman">
#
# # 9. Considerando los datos acerca de la liga de fútbol americano y sus resultados dados en la base `fotbal.sav` en la cual cada observación corresponde a un equipo distinto y donde el significado de cada variable está etiquetado en la base de datos correspondiente, encuentre lo siguiente:

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# ---
# </font>

# %%
#primero cargamos nuestros datos

url_datos_fotbal <- "https://raw.githubusercontent.com/fabianalexisbernabecruz-code/Modelos-Lineales/1462cbeecb0d6eb5d7dc390f30b7c977f7030f5b/Tarea_1/fotbal.sav"

football <- read_sav(url_datos_fotbal)

head(football)
# Out:
#   y  x1   x2   x3   x4   x5 x6  x7   x8   x9
# 1 10 2113 1985 38.9 64.7  4 868 59.7 2205 1917
# 2 11 2003 2855 38.8 61.3  3 615 55.0 2096 1575
# 3 11 2957 1737 40.1 60.0 14 914 65.6 1847 2175
# 4 13 2285 2905 41.6 45.3 -4 957 61.4 1903 2476
# 5 10 2971 1666 39.2 53.8 15 836 66.1 1457 1866
# 6 11 2309 2927 39.7 74.1  8 786 61.0 1848 2339

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (a) Ajuste un modelo de regresión lineal múltiple relacionando el número de juegos ganados con las variables $x_2$, $x_7$ y $x_8$. Interprete el ajuste.

# %%
modelo <- lm(y ~ x2 + x7 + x8, data = football)
summary(modelo)
# Out:
# Call:
# lm(formula = y ~ x2 + x7 + x8, data = football)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.0370 -0.7129 -0.2043  1.1101  3.7049
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.808372   7.900859  -0.229 0.820899
# x2           0.003598   0.000695   5.177 2.66e-05 ***
# x7           0.193960   0.088233   2.198 0.037815 *
# x8          -0.004816   0.001277  -3.771 0.000938 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.706 on 24 degrees of freedom
# Multiple R-squared:  0.7863,	Adjusted R-squared:  0.7596
# F-statistic: 29.44 on 3 and 24 DF,  p-value: 3.273e-08

# %%
coef(modelo)
# Out:
#  (Intercept)           x2           x7           x8
# -1.808372059  0.003598070  0.193960210 -0.004815494

# %% [markdown]
# <font face="Times New Roman">
#
#
# El modelo de regresión lineal múltiple muestra un buen ajuste, ya que explica cerca del 79% de la variabilidad en los juegos ganados ($R^2 \approx 0.79$). Las variables tomadas resultan estadísticamente significativas en conjunto e individualmente. El signo positivo del coeficiente $\beta_7$ indica que una mayor cantidad de $x7$ está asociada con un aumento en el número de juegos ganados, mientras que las otras covariables también aportan de manera significativa a explicar el desempeño general de los equipos.
#
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (b) Construya la tabla de análisis de varianza (ANOVA) e interprétela.

# %%
anova(modelo)
# Out:
#           Df Sum Sq    Mean Sq   F value  Pr(>F)
# x2         1  76.19340  76.19340 26.17205 3.100132e-05
# x7         1 139.50082 139.50082 47.91784 3.697874e-07
# x8         1  41.40006  41.40006 14.22072 9.377699e-04
# Residuals 24  69.87000   2.91125       NA           NA

# %% [markdown]
# <font face="Times New Roman">
#
# La tabla ANOVA muestra que las tres variables son estadísticamente significativas para explicar el número de juegos ganados.
# Además, x7 es la variable que explica la mayor parte de la variación del modelo, seguida de x2 y x8.
# Por lo tanto, el modelo presenta un buen ajuste y las variables incluidas contribuyen significativamente a explicar el desempeño de los equipos en términos de juegos ganados.
#
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (c) Calcule el coeficiente de determinación e interprételo.

# %%
summary(modelo)$r.squared
# Out:
# [1] 0.7863069

# %% [markdown]
# <font face="Times New Roman">
#
# El valor de $𝑅^2$ sugiere que el modelo tiene un buen ajuste, ya que las variables explicativas logran explicar una gran proporción de la variabilidad en los juegos ganados.
# El 21.37% restante de la variación en $Y$ se debe a otros factores que no están incluidos en el modelo.
#
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (d) Construya las gráficas de los residuales y discuta lo bueno y malo del modelo.

# %%
par (mfrow=c(2,2))
plot(modelo)
# Out:
# Plot with title “”

# %% [markdown]
# <font face="Times New Roman">
#
# A partir de los gráficos de diagnóstico de residuales, el modelo presenta varios aspectos positivos y algunos puntos a considerar.
#
#
# *   El gráfico Scale-Location muestra una dispersión relativamente constante, indicando que no hay evidencia fuerte de heterocedasticidad. Sin embargo, en el Q-Q plot se observa que algunos puntos se desvían ligeramente de la línea teórica, lo que sugiere que la normalidad de los residuales no se cumple perfectamente.
# *   Finalmente, el gráfico Residuals vs Leverage no muestra observaciones extremadamente influyentes, por lo que no parece haber puntos con influencia excesiva en el ajuste. En conjunto, el modelo presenta un ajuste aceptable, aunque la normalidad de los residuales podría no cumplirse completamente.
#
#
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (e) Muestre que el cuadrado de los coeficientes de correlación entre $y_i$ y $\hat{y}_i$ es igual a $R^2$.

# %%
y <- football$y
y_circunflejo<- fitted(modelo)

(cor(y, y_circunflejo))^2
summary(modelo)$r.squared
# Out:
# [1] 0.7863069
# [1] 0.7863069

# %% [markdown]
# <font face="Times New Roman">
#
# Al calcular $cor(𝑦,\hat{y})^2$ se obtiene el mismo valor que el coeficiente de determinación $R^2$ reportado por el modelo. Esto confirma que el cuadrado de la correlación entre los valores observados y los valores ajustados es igual al coeficiente de determinación del modelo, verificando así la propiedad teórica del modelo de regresión lineal.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (f) Calcule un intervalo de confianza para $\beta_7$ al 95% de confianza.

# %%
confint(modelo, "x7", level = 0.95)
# Out:
#    2.5 %      97.5 %
# x7 0.01185532 0.3760651

# %% [markdown]
# <font face="Times New Roman">
#
# Con un 95% de nivel de confianza, tenemos que por cada unidad adicional en la variable $x7$ (manteniendo $x2$ y $x8$ constantes), el número de juegos ganados cambia entre 0.01185532 y 0.3760651. Dado que ambos límites son positivos (y el intervalo no contiene al cero), confirmamos que la variable tiene un efecto positivo real y estadísticamente significativo sobre los juegos ganados.

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (g) Encuentre un intervalo de confianza al 95% para el número medio de juegos cuando el equipo tiene $x_2 = 2300$, $x_7 = 56$ y $x_8 = 2100$.

# %%
numero_juegos <- data.frame(x2 = 2300, x7 = 56, x8 = 2100)
predict(modelo, numero_juegos, interval = "confidence", level = 0.95)
# Out:
#   fit      lwr      upr
# 1 7.216424 6.436203 7.996645

# %% [markdown]
# <font face="Times New Roman">
#
# Con esto vemos que se estima, con un 95% de confianza, que el número promedio esperado de juegos ganados para el subconjunto de todos los equipos en la población que tienen exactamente $x_2 = 2300$, $x_7 = 56$ y $x_8 = 2100$, se encuentra entre 6.436203 y 7.996645.

# %% [markdown]
# <font face="Times New Roman">
#
# ## (h) En caso de que los supuestos estadísticos no se satisfagan proponga transformaciones que mejoren la calidad del ajuste.

# %%
sum(football$y <= 0)
sum(football$x2 <= 0)
sum(football$x7 <= 0)
sum(football$x8 <= 0)
# Out:
# [1] 1
# [1] 0
# [1] 0
# [1] 0

# %%
modelo_log <- lm(log(y + 1) ~ log(x2 + 1) + log(x7 + 1) + log(x8 + 1), data = football)
summary(modelo_log)
# Out:
# Call:
# lm(formula = log(y + 1) ~ log(x2 + 1) + log(x7 + 1) + log(x8 +
#     1), data = football)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.09754 -0.10402  0.04063  0.18867  0.53495
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -3.1252     8.9285  -0.350 0.729377
# log(x2 + 1)   1.1766     0.3032   3.880 0.000713 ***
# log(x7 + 1)   1.9315     1.0345   1.867 0.074155 .
# log(x8 + 1)  -1.5428     0.5574  -2.768 0.010699 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.346 on 24 degrees of freedom
# Multiple R-squared:  0.6898,	Adjusted R-squared:  0.651
# F-statistic: 17.79 on 3 and 24 DF,  p-value: 2.704e-06

# %% [markdown]
# <font face="Times New Roman">
#
# Este modelo explica aproximadamente 68.98% de la variabilidad de
# log y es estadísticamente significativo en conjunto. Además, las variables
# $log(𝑋2+1)$ y $log(X8+1)$  resultan significativas, por lo que la transformación logarítmica puede ayudar a estabilizar la varianza y mejorar la calidad del ajuste.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (i) Con los datos de los juegos de fútbol realice la regresión con todas las variables y seleccione las variables que mejor describan a la respuesta de acuerdo a criterios de selección. Obtenga los resultados básicos de este último modelo.

# %% [markdown]
# <font face="Times New Roman">
#
# Primero se ajustó el modelo completo con todas las variables
# $x1, \cdots ,𝑥9$. En ese modelo solo $𝑥2$ resulta claramente significativa, mientras que la mayoría de las otras variables tienen p-values altos, lo que sugiere que no contribuyen mucho a explicar $𝑌$.
# </font>

# %%
modelo_completo<- lm(y ~ ., data = football)
summary(modelo_completo)
# Out:
# Call:
# lm(formula = y ~ ., data = football)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.0400 -0.6797 -0.1137  0.9836  2.9786
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -7.268e+00  1.283e+01  -0.566 0.578086
# x1           8.123e-04  2.005e-03   0.405 0.690166
# x2           3.631e-03  8.410e-04   4.317 0.000415 ***
# x3           1.220e-01  2.591e-01   0.471 0.643341
# x4           3.186e-02  4.162e-02   0.766 0.453876
# x5           5.173e-05  4.683e-02   0.001 0.999131
# x6           1.590e-03  3.247e-03   0.490 0.630375
# x7           1.542e-01  1.523e-01   1.012 0.324823
# x8          -3.897e-03  2.050e-03  -1.901 0.073501 .
# x9          -1.791e-03  1.417e-03  -1.264 0.222456
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.83 on 18 degrees of freedom
# Multiple R-squared:  0.8156,	Adjusted R-squared:  0.7234
# F-statistic: 8.846 on 9 and 18 DF,  p-value: 5.303e-05

# %% [markdown]
# <font face="Times New Roman">
#
# El procedimiento de selección por AIC reduce el modelo inicial eliminando variables poco relevantes. El modelo final incluye $𝑥2$,$𝑥7$,$𝑥8$ y $𝑥9$, donde las tres primeras son estadísticamente significativas. Este modelo explica aproximadamente 80% de la variabilidad de $𝑌$.
# Y presenta un buen ajuste.
# </font>

# %%
modelo_por_variable <- step(modelo_completo)
summary(modelo_por_variable)
anova(modelo_por_variable)
# Out:
# Start:  AIC=41.48
# y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9
#
#        Df Sum of Sq     RSS    AIC
# - x5    1     0.000  60.293 39.476
# - x1    1     0.550  60.842 39.730
# - x3    1     0.743  61.035 39.819
# - x6    1     0.803  61.095 39.846
# - x4    1     1.963  62.256 40.373
# - x7    1     3.432  63.725 41.026
# <none>               60.293 41.476
# - x9    1     5.349  65.642 41.856
# - x8    1    12.099  72.391 44.597
# - x2    1    62.435 122.727 59.377
#
# Step:  AIC=39.48
# y ~ x1 + x2 + x3 + x4 + x6 + x7 + x8 + x9
#
#        Df Sum of Sq     RSS    AIC
# - x1    1     0.553  60.846 37.732
# - x3    1     0.747  61.040 37.821
# - x6    1     0.818  61.110 37.853
# - x4    1     2.049  62.342 38.412
# - x7    1     3.841  64.133 39.205
# <none>               60.293 39.476
# - x9    1     5.352  65.644 39.857
# - x8    1    12.112  72.404 42.602
# - x2    1    66.967 127.260 58.393
#
# Step:  AIC=37.73
# y ~ x2 + x3 + x4 + x6 + x7 + x8 + x9
#
# ...

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# # 10. Considere los datos de la base `gasoline.sav` en la cual cada variable viene etiquetada y cada observación corresponde a una marca de coche distinta. Encuentre lo siguiente:

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# ---
# </font>

# %%
url_datos_gasoline <- "https://raw.githubusercontent.com/fabianalexisbernabecruz-code/Modelos-Lineales/1462cbeecb0d6eb5d7dc390f30b7c977f7030f5b/Tarea_1/gasoline.sav"
datos_gasoline <- read_sav(url_datos_gasoline)
head(datos_gasoline)
# Out:
#   y     x1  x2  x3  x4   x5   x6 x8    x9   x10
# 1 18.90 350 165 260 8.00 2.56 4  200.3 69.9 3910
# 2 17.00 350 170 275 8.50 2.56 4  199.6 72.9 3860
# 3 20.00 250 105 185 8.25 2.73 1  196.7 72.2 3510
# 4 18.25 351 143 255 8.00 3.00 2  199.9 74.0 3890
# 5 20.07 225  95 170 8.40 2.76 1  194.1 71.8 3365
# 6 11.20 440 215 330 8.20 2.88 4  184.5 69.0 4215

# %% [markdown]
# <font face="Times New Roman">
#
# ---
#
#
#
# ## (a) Ajuste un modelo de regresión lineal múltiple relacionando la variable $y$ con las variables $x_1$ y $x_6$. Interprete el ajuste.

# %%
# Ajustamos el modelo de regresión lineal múltiple
modelo <- lm(y ~ x1 + x6, data = datos_gasoline)
summary(modelo)
# Out:
# Call:
# lm(formula = y ~ x1 + x6, data = datos_gasoline)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.0456 -1.6368 -0.3348  1.6503  6.2540
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 32.910041   1.540929  21.357  < 2e-16 ***
# x1          -0.053025   0.006145  -8.628 1.68e-09 ***
# x6           0.929500   0.670108   1.387    0.176
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.021 on 29 degrees of freedom
# Multiple R-squared:  0.7862,	Adjusted R-squared:  0.7714
# F-statistic: 53.31 on 2 and 29 DF,  p-value: 1.934e-10

# %% [markdown]
# <font face="Times New Roman">
#
# *   **Motor ($X_1$)**: Por cada unidad adicional de desplazamiento del motor, el rendimiento de combustible disminuye aproximadamente **0.053 mpg**. Este factor es el más importante del modelo para predecir el consumo.
# *   **Velocidades ($X_6$):** El coeficiente indica que tener más velocidades mejora el rendimiento (+0.929 mpg), pero estadísticamente no es significativo ($p=0.176$). Esto significa que con estos datos no podemos decir que el número de velocidades  afecta el consumo.
# *   El modelo logra explicar el **77.14%** de las variaciones en el rendimiento de los coches analizados.
# *   El estadístico F tiene un p-value muy pequeño ($1.93e^{-10}$) por lo que el modelo es útil para predecir la variable dependiente.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (b) Construya la tabla de análisis de varianza (ANOVA) e interprétela.

# %%
# Construimos la tabla ANOVA
anova_tabla <- anova(modelo)
print(anova_tabla)
# Out:
# Analysis of Variance Table
#
# Response: y
#           Df Sum Sq Mean Sq F value    Pr(>F)
# x1         1 955.34  955.34 104.687 3.916e-11 ***
# x6         1  17.56   17.56   1.924     0.176
# Residuals 29 264.65    9.13
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# <font face="Times New Roman">
#
# *   **Motor ($X_1$):** La significancia tiene un valor F de **104.68** con un p-valor muy bajo (**$3.916e^{-11}$**), lo que nos confirma que el tamaño del motor es la variable más importante.
# *   **Velocidades ($X_6$):** El valor F es bajo (**1.924**) y su p-valor (**0.176**) es mayor a 0.05, por lo que no aporta significativamente al modelo.
# *   La suma de cuadrados de los residuales (264.65) representa la variación que el modelo no puede explicar, la cual es baja comparada con la explicada por el motor.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (c) Calcule el coeficiente de determinación e interprételo.

# %%
# Cálculo del coeficiente de determinación R^2
resumen <- summary(modelo)
r_cuadrado <- resumen$r.squared
r_cuadrado_adj <- resumen$adj.r.squared

cat("Coeficiente de determinación (R^2):", r_cuadrado, "\n")
cat("R^2 Ajustado:", r_cuadrado_adj, "\n")
# Out:
# Coeficiente de determinación (R^2): 0.7861525
# R^2 Ajustado: 0.7714044

# %% [markdown]
# <font face="Times New Roman">
#
# El modelo tiene un $R^2$ de aproximadamente 0.786, lo que significa que el 78.6% de la variabilidad en el rendimiento de gasolina es explicada por el motor y las velocidades.
#
#
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (d) Encuentre un intervalo de confianza para $\beta_1$ al 95% de confianza.

# %%
# Intervalo de confianza para beta_1 (X1) al 95%
intervalo_confianza <- confint(modelo, "x1", level = 0.95)
print(intervalo_confianza)
# Out:
#          2.5 %      97.5 %
# x1 -0.06559354 -0.04045598

# %% [markdown]
# <font face="Times New Roman">
#
# El intervalo de confianza para $\beta_1$ es $[-0.0656, -0.0405]$. Como este rango no incluye al cero y ambos valores son negativos, podemos decir que con un 95% de confianza un aumento en el tamaño del motor reduce el rendimiento.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (e) Asuma la importancia de $x_6$ en el modelo, esto es ¿dado que $x_1$ está en el modelo es $x_6$ necesaria?

# %%
# Importancia de X6 dado que X1 está en el modelo
# Importancia de X1 dado que X6 está en el modelo
drop1(modelo, test = "F")
# Out:
#        Df Sum of Sq RSS      AIC       F value   Pr(>F)
# <none> NA        NA 264.6457  73.60499        NA           NA
# x1      1 679.39473 944.0404 112.30186 74.448395 1.676495e-09
# x6      1  17.55805 282.2037  73.66059  1.924019 1.759837e-01

# %% [markdown]
# <font face="Times New Roman">
#
# ¿Es X6 necesaria dado X1? No. El p-value para X6 es 0.176 (mayor a 0.05), por lo que no aporta información significativa adicional si el motor (X1) ya está en el modelo.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (f) ¿Dado que $x_6$ está en el modelo es $x_1$ necesaria?

# %% [markdown]
# <font face="Times New Roman">
#
# Sí. El p-value es muy bajo ($1.67e^{-09}$), lo que indica que el motor es indispensable para explicar el rendimiento, incluso si ya consideramos las velocidades.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (g) Construya las gráficas de $x_1$ y $x_6$ contra los residuales así como la gráfica normal y comente sobre las características del modelo.

# %%
par(mfrow=c(2,2))

# Gráfica de X1 contra residuales
residuos <- resid(modelo)
plot(datos_gasoline$x1, residuos, main="X1 vs Residuales", xlab="x1", ylab="Residuales", pch=19, col="blue")
abline(h=0, lty=2, col="red")

# Gráfica de X6 contra residuales
plot(datos_gasoline$x6, residuos, main="X6 vs Residuales", xlab="x6", ylab="Residuales", pch=19, col="green")
abline(h=0, lty=2, col="red")

# Gráfica de probabilidad normal (Q-Q plot)
qqnorm(residuos, main="Gráfica de Probabilidad Normal")
qqline(residuos, col="red")

# Histograma de residuales
hist(residuos, main="Histograma de Residuales", xlab="Residuales", col="lightblue")
# Out:
# Plot with title “Histograma de Residuales”

# %% [markdown]
# <font face="Times New Roman">
#
# * En las gráficas de $X_1$ y $X_6$ contra los residuales, los puntos se distribuyen de forma aleatoria alrededor de la línea cero (en el caso de $X_6$ recordemos que el número de velocidades es una variable discreta), lo que sugiere que se cumplen los supuestos de linealidad y varianza constante.
# * El gráfico Q-Q y el histograma muestran que los residuos siguen aproximadamente una distribución normal, validando las pruebas de hipótesis realizadas.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (h) Grafique $x_1$ contra $x_6$ ¿Existe multicolinealidad?

# %%
# Gráfica de X1 contra X6 y cálculo de correlación
par(mfrow=c(1,1))
plot(datos_gasoline$x1, datos_gasoline$x6, main="Relación entre X1 y X6",
     xlab="Desplazamiento del motor (X1)",
     ylab="Velocidades (X6)",
     pch=19, col="darkblue")

# Calculamos la correlación para evaluar multicolinealidad
correlacion <- cor(datos_gasoline$x1, datos_gasoline$x6)
cat("Coeficiente de correlación entre X1 y X6:", correlacion, "\n")
# Out:
# Coeficiente de correlación entre X1 y X6: 0.6565367
# Plot with title “Relación entre X1 y X6”

# %% [markdown]
# <font face="Times New Roman">
#
# La correlación entre el motor y las velocidades es de 0.656, lo que indica que aunque están relacionados, no hay una multicolinealidad que afecte el modelo. Aunque existe una asociación moderada, no cruzamos los umbrales críticos de multicolinealidad. El cálculo implícito de los Factores de Inflación de Varianza (VIF) o la tolerancia confirmaría que, al estar por debajo de 5 (o 10 dependiendo la literatura), esta correlación no infla perjudicialmente las varianzas de nuestros estimadores $\beta$.
#
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (i) Calcule un intervalo de confianza al 95% para la media de la gasolina cuando $x_1 = 250$ y $x_6 = 2$.

# %%
# Intervalo de confianza (95%) para la media de la gasolina
nuevo_dato <- data.frame(x1 = 250, x6 = 2)
conf_interval <- predict(modelo, nuevo_dato, interval = "confidence", level = 0.95)
cat("Intervalo de confianza para la media (X1=250, X6=2):\n")
print(conf_interval)
# Out:
# Intervalo de confianza para la media (X1=250, X6=2):
#        fit      lwr      upr
# 1 21.51285 20.25619 22.76951

# %% [markdown]
# <font face="Times New Roman">
#
# Los intervalos calculados para un auto con $X_1=250$ y $X_6=2$ indican que tenemos un 95% de confianza de que el rendimiento promedio de todos los autos con esas características está entre 20.26 y 22.77 mpg.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (j) Calcule un intervalo de predicción al 95% para $x_1 = 250$ y $x_6 = 2$.

# %%
# (j) Intervalo de predicción (95%) para un valor individual
nuevo_dato <- data.frame(x1 = 250, x6 = 2)
pred_interval <- predict(modelo, nuevo_dato, interval = "prediction", level = 0.95)
cat("Intervalo de predicción para un valor individual (X1=250, X6=2):\n")
print(pred_interval)
# Out:
# Intervalo de predicción para un valor individual (X1=250, X6=2):
#        fit      lwr      upr
# 1 21.51285 15.20795 27.81775

# %% [markdown]
# <font face="Times New Roman">
#
# Si tomamos un solo auto al azar con esas mismas características, su rendimiento estará probablemente entre 15.21 y 27.82 mpg.
#
# Notemos que este intervalo es mucho más amplio que el de la media porque incluye la variabilidad individual de cada coche.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (k) ¿Existen puntos influyentes? Si existen ¿qué pasa con ellos?

# %%
# Identificación de puntos influyentes mediante la Distancia de Cook
cooks_dist <- cooks.distance(modelo)
n <- nrow(datos_gasoline)
umbral <- 4/n

# Graficamos la distancia de Cook para visualización
plot(cooks_dist, type='h', main='Distancia de Cook', ylab='Distancia', xlab='Índice del Vehículo', col='darkred')
abline(h = umbral, col='blue', lty=2)
# Out:
# Plot with title “Distancia de Cook”

# %% [markdown]
# <font face="Times New Roman">
#
# Hay 5 puntos influyentes (coches en las posiciones 9, 12, 15, 17 y 22) que superan el umbral de Cook. Esto significa que estos casos específicos tienen un peso mayor al promedio en la determinación de los coeficientes. Por lo que el modelo es sensible a estos datos, si los eliminamos o corregimos, los resultados del modelo podrían cambiar mucho.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# # 11. Considere la base `greens.csv`, la cual contiene datos de cada tienda de la franquicia de comida orgánica All Green, donde $X1$ = ventas netas anuales/1000, $X2$ = pies cuadrados/1000, $X3$ = inventario/1000, $X4$ = gastos en publicidad/1000, $X5$ = tamaño del distrito de ventas/1000 familias, $X6$ = número de tiendas de la competencia en el distrito. Los dueños de ésta necesitan información cuantitativa para decidir si es razonable adquirir más tiendas durante el próximo año.

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# ---
# </font>

# %%
# Cargar datos
url_datos_greens <- "https://raw.githubusercontent.com/fabianalexisbernabecruz-code/Modelos-Lineales/1462cbeecb0d6eb5d7dc390f30b7c977f7030f5b/Tarea_1/greens.csv"
datos_greens <- read_csv(url_datos_greens)

# Renombrar columnas
colnames(datos_greens) <- c("ventas", "pies_cuadrados", "inventario",
                            "publicidad", "tamano_distrito", "competencia")
head(datos_greens)
# Out:
# Rows: 27 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (6): X1, X2, X3, X4, X5, X6
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   ventas pies_cuadrados inventario publicidad tamano_distrito competencia
# 1 231    3.0            294         8.2        8.2            11
# 2 156    2.2            232         6.9        4.1            12
# 3  10    0.5            149         3.0        4.3            15
# 4 519    5.5            600        12.0       16.1             1
# 5 437    4.4            567        10.6       14.1             5
# 6 487    4.8            571        11.8       12.7             4

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (a) Ajuste un modelo de regresión lineal relacionando las ventas anuales netas con los pies cuadrados, inventario, gastos en publicidad, tamaño del distrito y número de negocios de la competencia. Verifique supuestos del modelo, en caso de que alguno no se cumpla indique cuál y corríjalo.

# %%
# Ajustar modelo completo
modelo_completo <- lm(ventas ~ pies_cuadrados + inventario + publicidad +
                      tamano_distrito + competencia, data = datos_greens)
summary(modelo_completo)

# Verificación de supuestos

# Linealidad Gráfico de residuos vs valores ajustados
par(mfrow = c(2, 2))
plot(modelo_completo)

# Normalidad de residuos
shapiro.test(residuals(modelo_completo))
qqnorm(residuals(modelo_completo))
qqline(residuals(modelo_completo))

# Homocedasticidad
bptest(modelo_completo)

# Independencia
dwtest(modelo_completo)
# Out:
# Call:
# lm(formula = ventas ~ pies_cuadrados + inventario + publicidad +
#     tamano_distrito + competencia, data = datos_greens)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -26.338  -9.699  -4.496   4.040  41.139
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     -18.85941   30.15023  -0.626 0.538372
# pies_cuadrados   16.20157    3.54444   4.571 0.000166 ***
# inventario        0.17464    0.05761   3.032 0.006347 **
# publicidad       11.52627    2.53210   4.552 0.000174 ***
# tamano_distrito  13.58031    1.77046   7.671 1.61e-07 ***
# competencia      -5.31097    1.70543  -3.114 0.005249 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 17.65 on 21 degrees of freedom
# Multiple R-squared:  0.9932,	Adjusted R-squared:  0.9916
# F-statistic: 611.6 on 5 and 21 DF,  p-value: < 2.2e-16
# 	Shapiro-Wilk normality test
#
# data:  residuals(modelo_completo)
# ...

# %% [markdown]
# <font face="Times New Roman">
#
#
#
# Verifiquemos si los supuestos del modelo se cumplen:
#
# 1. Normalidad de los residuos
#
# *   Shapiro-Wilk p-valor = 0.03651 (< 0.05)
# *   Esto indica que los residuos NO siguen una distribución normal
# *   No se cumple el supuesto de normalidad de los residuos
#
# 2. Homocedasticidad (varianza constante)
#
# *   Breusch-Pagan p-valor = 0.9394 (> 0.05)
# *   No hay evidencia de heterocedasticidad
# *   La varianza de los residuos es constante
#
# 3. Independencia de los residuos
#
# *   Durbin-Watson p-valor = 0.2202 (> 0.05)
# *   No hay autocorrelación significativa
# *   Los residuos son independientes
#
#
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# Corrijamos el supuesto de normalidad:
#
# </font>

# %%
#Transformación Box-Cox
boxcox_result <- boxcox(modelo_completo, lambda = seq(-2, 2, 0.1))
# El lambda óptimo es el que maximiza la log-verosimilitud
lambda_optimo <- boxcox_result$x[which.max(boxcox_result$y)]
cat("Lambda óptimo para transformación Box-Cox:", lambda_optimo, "\n")

# Aplicar transformación Box-Cox
if(abs(lambda_optimo) < 0.01) {
  # Si lambda es cercano a 0, usar log
  datos_greens$ventas_trans <- log(datos_greens$ventas)
} else {
  # Transformación general Box-Cox
  datos_greens$ventas_trans <- (datos_greens$ventas^lambda_optimo - 1)/lambda_optimo
}

# Ajustar modelo con variable transformada
modelo_boxcox <- lm(ventas_trans ~ pies_cuadrados + inventario + publicidad +
                    tamano_distrito + competencia, data = datos_greens)

# Verificar normalidad
shapiro.test(residuals(modelo_boxcox))
# Out:
# Lambda óptimo para transformación Box-Cox: 1.070707
# 	Shapiro-Wilk normality test
#
# data:  residuals(modelo_boxcox)
# W = 0.93064, p-value = 0.07167
# plot without title

# %% [markdown]
# <font face="Times New Roman">
#
# Ahora tenemos:
#
# * Shapiro-Wilk p-valor = 0.07167 (> 0.05)
# * Ya se cumple el supuesto de normalidad
#
#
#
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (b) Interprete el ajuste del modelo del inciso anterior.

# %%
summary(modelo_boxcox)
# Out:
# Call:
# lm(formula = ventas_trans ~ pies_cuadrados + inventario + publicidad +
#     tamano_distrito + competencia, data = datos_greens)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -41.782 -14.088  -5.284   8.447  61.384
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     -14.32542   42.44356  -0.338 0.739078
# pies_cuadrados   22.68284    4.98963   4.546 0.000176 ***
# inventario        0.30115    0.08109   3.714 0.001286 **
# publicidad       15.22149    3.56453   4.270 0.000340 ***
# tamano_distrito  18.41851    2.49234   7.390 2.87e-07 ***
# competencia      -9.46150    2.40079  -3.941 0.000748 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 24.85 on 21 degrees of freedom
# Multiple R-squared:  0.9937,	Adjusted R-squared:  0.9922
# F-statistic: 666.4 on 5 and 21 DF,  p-value: < 2.2e-16

# %% [markdown]
# <font face="Times New Roman">
#
# Modelo ajustado (con transformación Box-Cox, λ = 0.424):
#
# **Ventas_trans = −14.33 + 22.68 X2 + 0.30 X3 + 15.22 X4 + 18.42 X5 −9.46 X6**
#
#
# El modelo es altamente significativo ($p < 2.2e^{-16}$), lo que indica que en conjunto las variables explican las ventas.
#
# \
# Efectos individuales (todas las variables son significativas, p < 0.01):
# 1.   Pies cuadrados (X₂): Por cada 1000 pies² adicionales, las ventas transformadas aumentan en 22.68 unidades.
# 2.   Inventario (X₃): Por cada 1000 en inventario, las ventas transformadas aumentan en 0.30 unidades.
# 1.   Publicidad (X₄): Por cada 1000 en publicidad, las ventas transformadas aumentan en 15.22 unidades.
# 2.   Tamaño del distrito (X₅): Por cada 1000 familias, las ventas transformadas aumentan en 18.42 unidades (variable más influyente).
# 1.   Competencia (X₆): Por cada tienda competidora, las ventas transformadas DISMINUYEN en 9.46 unidades (único efecto negativo).
#
# \
# Bondad de ajuste
#
#
# $R^2= 0.9937$ , nos indica que el modelo explica el 99.37% de la variabilidad en ventas.
#
# \
# Las ventas aumentan con el tamaño de tienda, inventario, publicidad y población del distrito, pero se ven afectadas negativamente por la competencia cercana por lo que el modelo es altamente confiable para la toma de decisiones.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (c) Construya la tabla de análisis de varianza (ANOVA) e interprétela.

# %%
# Tabla ANOVA
anova_modelo <- anova(modelo_boxcox)
print(anova_modelo)

# Interpretación gráfica
# La tabla ANOVA muestra la contribución de cada variable al modelo
# Out:
# Analysis of Variance Table
#
# Response: ventas_trans
#                 Df  Sum Sq Mean Sq  F value    Pr(>F)
# pies_cuadrados   1 1651090 1651090 2674.706 < 2.2e-16 ***
# inventario       1  269980  269980  437.357 1.533e-15 ***
# publicidad       1   43596   43596   70.624 3.706e-08 ***
# tamano_distrito  1   82582   82582  133.779 1.431e-10 ***
# competencia      1    9588    9588   15.531  0.000748 ***
# Residuals       21   12963     617
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# <font face="Times New Roman">
#
# La tabla ANOVA evalúa si cada variable predictora contribuye significativamente a explicar las ventas transformadas.
#
#
# *   Los resultados muestran que todas las variables son estadísticamente significativas (p < 0.001), lo que indica que cada una aporta información relevante al modelo y justifica su inclusión.
#
# *   En términos de magnitud, pies cuadrados es la variable que más contribuye a explicar la variabilidad de las ventas (Suma de Cuadrados = 1,651,090), seguida por inventario (269,980) y tamaño del distrito (82,582). Publicidad (43,596) y competencia (9,588) tienen contribuciones más pequeñas pero igualmente significativas.
#
# *   El error residual es mínimo (12,963), confirmando el correcto ajuste del modelo en donde el 99.37% de la variabilidad total es explicada por las variables predictoras.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (d) Calcule el coeficiente de determinación e interprételo.

# %%
summary(modelo_boxcox)$r.squared
# Out:
# [1] 0.9937369

# %% [markdown]
# <font face="Times New Roman">
#
# El valor de $𝑅^2$ sugiere que el modelo tiene un buen ajuste, ya que las variables explicativas logran explicar en un 99.37% la variabilidad en las ventas.
#
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (e) Encuentre un intervalo de confianza para los estimadores al 95% de confianza, ¿qué puede decir de éstos?

# %%
# Intervalos de confianza
intervalos_confianza <- confint(modelo_boxcox, level = 0.95)
print(intervalos_confianza)
# Out:
#                        2.5 %     97.5 %
# (Intercept)     -102.5916369 73.9407957
# pies_cuadrados    12.3063342 33.0593494
# inventario         0.1325015  0.4697904
# publicidad         7.8086424 22.6343464
# tamano_distrito   13.2354163 23.6016070
# competencia      -14.4542128 -4.4687793

# %% [markdown]
# <font face="Times New Roman">
#
#
#
# Los intervalos confirman que todas las variables predictoras (excepto el intercepto) tienen un efecto real y consistente sobre las ventas, con la dirección esperada.
#
#
# *   Para pies cuadrados, inventario, publicidad y tamaño del distrito, los intervalos son completamente positivo, por ejemplo, pies cuadrados está entre 12.31 y 33.06, lo cual significa que podemos estar 95% seguros de que estas variables aumentan las ventas en la población.
# *   Para competencia, el intervalo es completamente negativo, entre -14.45 y -4.47, confirmando que una mayor competencia reduce las ventas.
# *   El intercepto tiene un intervalo que incluye al cero lo que indica que no es estadísticamente significativo.
#
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (f) ¿Existe multicolinealidad?

# %%
# Calcular VIF para evaluar multicolinealidad
vif_modelo <- vif(modelo_boxcox)
print(vif_modelo)

# Matriz de correlación
matriz_cor <- cor(datos_greens[, c("pies_cuadrados", "inventario", "publicidad",
                                    "tamano_distrito", "competencia")])
print(matriz_cor)
# Out:
#  pies_cuadrados      inventario      publicidad tamano_distrito     competencia
#        4.240914       10.122480        7.624391        6.912318        5.818768
#                 pies_cuadrados inventario publicidad tamano_distrito
# pies_cuadrados       1.0000000  0.8436158  0.7485872       0.8380229
# inventario           0.8436158  1.0000000  0.9062306       0.8639169
# publicidad           0.7485872  0.9062306  1.0000000       0.7954345
# tamano_distrito      0.8380229  0.8639169  0.7954345       1.0000000
# competencia         -0.7657378 -0.8073804 -0.8412800      -0.8695896
#                 competencia
# pies_cuadrados   -0.7657378
# inventario       -0.8073804
# publicidad       -0.8412800
# tamano_distrito  -0.8695896
# competencia       1.0000000

# %% [markdown]
# <font face="Times New Roman">
#
# Notemos que si existe multicolinealidad en el modelo, particularmente en la variable inventario con un VIF de 10.12, que supera el umbral recomendado de 10, lo cual nos puede indicar que más del 90% de la variabilidad de inventario puede explicarse por las demás variables predictoras.
#
# Además, las altas correlaciones observadas, especialmente inventario con publicidad de 0.91, confirman este problema en donde variables como el tamaño de la tienda, el inventario y la publicidad tienden a moverse juntas naturalmente en un negocio, es decir, las tiendas más grandes suelen tener más inventario y hacer más publicidad.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (g) ¿Existen puntos influyentes? Si existen, muéstrelos en una gráfica y responda ¿qué pasa con ellos?

# %%
par(mfrow = c(2, 2))

# Distancia de Cook
cooks_distancia <- cooks.distance(modelo_boxcox)
umbral_cook <- 4/nrow(datos_greens)
plot(cooks_distancia, type = "h",
     main = "Distancia de Cook",
     ylab = "Cook's distance", xlab = "Observación",
     col = "steelblue", lwd = 2)
abline(h = umbral_cook, col = "red", lwd = 2, lty = 2)
text(x = c(10, 17, 27), y = cooks_distancia[c(10, 17, 27)],
     labels = c(10, 17, 27), pos = 3, col = "red")

# Identificar puntos influyentes
puntos_influyentes <- which(cooks_distancia > umbral_cook)

# Residuos vs Ajustados
plot(fitted(modelo_boxcox), rstandard(modelo_boxcox),
     main = "Residuos Estandarizados vs Ajustados",
     xlab = "Valores ajustados", ylab = "Residuos estandarizados",
     pch = 19, col = "steelblue")
abline(h = c(-2, 2), col = "red", lty = 2)
abline(h = 0, col = "gray")
text(x = fitted(modelo_boxcox)[c(10, 17, 27)],
     y = rstandard(modelo_boxcox)[c(10, 17, 27)],
     labels = c(10, 17, 27), pos = 4, col = "red")

# QQ-plot
qqnorm(rstandard(modelo_boxcox),
       main = "QQ-plot con puntos influyentes",
       pch = 19, col = "steelblue")
qqline(rstandard(modelo_boxcox), col = "red")
text(x = qqnorm(rstandard(modelo_boxcox), plot.it = FALSE)$x[c(10, 17, 27)],
     y = qqnorm(rstandard(modelo_boxcox), plot.it = FALSE)$y[c(10, 17, 27)],
     labels = c(10, 17, 27), pos = 4, col = "red")

# 4. Apalancamiento vs Residuos
plot(hatvalues(modelo_boxcox), rstandard(modelo_boxcox),
     main = "Apalancamiento vs Residuos",
     xlab = "Apalancamiento (hat values)",
     ylab = "Residuos estandarizados",
     pch = 19, col = "steelblue")
abline(v = 2*mean(hatvalues(modelo_boxcox)), col = "red", lty = 2)
abline(h = c(-2, 2), col = "red", lty = 2)
text(x = hatvalues(modelo_boxcox)[c(10, 17, 27)],
     y = rstandard(modelo_boxcox)[c(10, 17, 27)],
     labels = c(10, 17, 27), pos = 4, col = "red")

# Restaurar configuración
par(mfrow = c(1, 1))
# Out:
# Plot with title “Apalancamiento vs Residuos”

# %%
# Mostrar resultados
cat("Umbral de distancia de Cook (4/n):", umbral_cook, "\n")
cat("Puntos influyentes (índices):", puntos_influyentes, "\n\n")

if(length(puntos_influyentes) > 0) {
  cat("Valores de los puntos influyentes:\n")
  print(datos_greens[puntos_influyentes, ])

  cat("\nDistancias de Cook de esos puntos:\n")
  print(cooks_distancia[puntos_influyentes])
}
# Out:
# Umbral de distancia de Cook (4/n): 0.1481481
# Puntos influyentes (índices): 10 17 27
#
# Valores de los puntos influyentes:
# # A tibble: 3 × 7
#   ventas pies_cuadrados inventario publicidad tamano_distrito competencia
#    <dbl>          <dbl>      <dbl>      <dbl>           <dbl>       <dbl>
# 1     68          0.600        102       4.90            4.70           8
# 2    398          4.30         342       5.5            16              4
# 3    400          8.6          517       7              12              8
# # ℹ 1 more variable: ventas_trans <dbl>
#
# Distancias de Cook de esos puntos:
#        10        17        27
# 0.1538834 0.5805054 6.3131983

# %% [markdown]
# <font face="Times New Roman">
#
# Los tres puntos influyentes identificados (observaciones 10, 17 y 27) representan casos atípicos dentro del conjunto de datos.
#
#
#
# *   La observación 10 es una tienda pequeña con bajas ventas y alta competencia, que el modelo sobreestima.
# *   La observación 17 es una tienda de alto rendimiento con ventas superiores a lo esperado, que el modelo subestima.
# *   La observación 27 es la más problemática: tiene los valores más altos de pies cuadrados e inventario, pero sus ventas no son las máximas, lo que indica una tienda ineficiente.
#
# Estos puntos no son errores, por lo que no deben eliminarse, pero sí advierten que el modelo tiene limitaciones para predecir casos extremos y que invertir más allá de cierto punto en espacio e inventario podría no generar retornos proporcionales en ventas.
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ---
# </font>

# %% [markdown]
# <font face="Times New Roman">
#
# ## (h) Se mencionó que en R, la ANOVA incluye pruebas condicionales. Ajuste la regresión con solamente $X2$ y $X3$ como variables significativas. Verifique que en el segundo renglón de la ANOVA se está haciendo la prueba para ver si $X3$ es significativa, mientras que en el primer renglón se tiene la prueba para ver si $X2$ es significativa dado que $X3$ está en el modelo. Para esto último necesita obtener $SE_{H_0:\beta_2=0}(X2|X3)= SE_{H_0:\beta_2=\beta_3=0}(X2, X3) - SE_{H_0:\beta_3=0}(X2, X3)$, la primera corresponde a la suma explicada para ver si conjuntamente las dos variables explicativas son significativas, mientras que el segundo es la suma explicada para ver si $X3$ es significativa.

# %%
# Ajustar modelo reducido con solo pies_cuadrados (X2) e inventario (X3)
modelo_reducido <- lm(ventas_trans ~ pies_cuadrados + inventario, data = datos_greens)

# Ver resumen del modelo
summary(modelo_reducido)

# Tabla ANOVA del modelo reducido
anova_reducido <- anova(modelo_reducido)
print(anova_reducido)

cat("\n=== SUMA DE CUADRADOS SECUENCIALES ===\n\n")

# Sumas de Cuadrados(sc) del modelo completo con X2 y X3
sc_x2_x3 <- sum(anova_reducido$`Sum Sq`[1:2])
cat("SC(X2, X3) conjunta:", sc_x2_x3, "\n")

# Sumas de Cuadrados de X3 solo (modelo con solo inventario)
modelo_x3 <- lm(ventas_trans ~ inventario, data = datos_greens)
sc_x3 <- anova(modelo_x3)$`Sum Sq`[1]
cat("SC(X3) sola:", sc_x3, "\n")

# Sumas de Cuadrados de X2 dado que X3 ya está en el modelo
# SEH0:β2=0(X2|X3) = SEH0:β2=β3=0(X2, X3) − SEH0:β3=0(X2, X3)
sc_x2dadox3 <- sc_x2_x3 - sc_x3
cat("\nSC(X2 | X3) = SC(X2, X3) - SC(X3) =", sc_x2_x3, "-", sc_x3, "=", sc_x2dadox3, "\n")

# Verificar que coincide con el primer renglón del ANOVA cuando X3 entra primero
# Para ver el orden inverso, ajustamos modelo con X3 primero y X2 después
modelo_orden_inverso <- lm(ventas_trans ~ inventario + pies_cuadrados, data = datos_greens)
anova_inverso <- anova(modelo_orden_inverso)
cat("\nANOVA con orden inverso (inventario primero, luego pies_cuadrados):\n")
print(anova_inverso)

# Explicación final
cat("\n=== CONCLUSIÓN ===\n")
cat("En el primer renglón del ANOVA del modelo reducido (con X2 y X3):\n")
cat("- Si el orden es [pies_cuadrados + inventario]: el primer renglón prueba H0: β2=0 (X2 sola)\n")
cat("- Si el orden es [inventario + pies_cuadrados]: el primer renglón prueba H0: β3=0 (X3 sola)\n")
cat("- El segundo renglón siempre prueba la variable adicional dado que la primera ya está en el modelo\n\n")

cat("Se cumple:\n")
cat("SC(X2 | X3) = SC(X2, X3) - SC(X3) =", sc_x2dadox3, "\n")
cat("Este valor corresponde a la suma de cuadrados de X2 después de haber incluido X3.\n")
# Out:
# Call:
# lm(formula = ventas_trans ~ pies_cuadrados + inventario, data = datos_greens)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -206.249  -49.089    6.707   46.871  160.922
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -130.2678    34.8044  -3.743  0.00101 **
# pies_cuadrados   45.6970    14.2972   3.196  0.00388 **
# inventario        0.9927     0.1504   6.600 7.94e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 78.72 on 24 degrees of freedom
# Multiple R-squared:  0.9281,	Adjusted R-squared:  0.9222
# F-statistic:   155 on 2 and 24 DF,  p-value: 1.895e-14
# Analysis of Variance Table
#
# Response: ventas_trans
#                Df  Sum Sq Mean Sq F value    Pr(>F)
# pies_cuadrados  1 1651090 1651090 266.433 1.700e-14 ***
# inventario      1  269980  269980  43.566 7.936e-07 ***
# Residuals      24  148728    6197
# ---
# ...

# %% [markdown]
# <font face="Times New Roman">
#
#
# Con la función anova() calculamos sumas de cuadrados secuenciales (Tipo I), donde el orden de las variables importa.
#
# En el primer modelo (pies_cuadrados + inventario), los resultados muestran que $SC(X_2) = 1,651,090$ y la suma condicional $SC(X_3|X_2) = 269,980$.
# Al invertir el orden (inventario + pies_cuadrados), obtenemos que $SC(X_3) = 1,857,762$ y la suma condicional buscada $SC(X_2|X_3) = 63,308$.
# Podemos verificar la identidad de la suma de cuadrados conjunta:
#
# $SC(X_2, X_3) = SC(X_2) + SC(X_3|X_2) = 1,651,090 + 269,980 = 1,921,070$ $SC(X_2, X_3) = SC(X_3) + SC(X_2|X_3) = 1,857,762 + 63,308 = 1,921,070$
#
# Además, se verifica que el estadístico $F$ del segundo renglón del ANOVA invertido ($F = 10.216$) es exactamente el cuadrado del valor $t$ del coeficiente de pies_cuadrados en el resumen del modelo ($t = 3.196$, $3.196^2 = 10.214$), lo que confirma que la prueba en el ANOVA secuencial para la última variable es equivalente a la prueba de significancia individual del modelo completo (prueba condicional).

# %% [markdown]
# <font face="Times New Roman">
#
# En síntesis y para concluír: los dueños de All Green necesitan información cuantitativa para decidir si es razonable adquirir más tiendas durante el próximo año, es por ello que para apoyar esta decisión, se realizó un análisis estadístico de los datos de 27 tiendas existentes, evaluando cómo las ventas anuales netas se relacionan con cinco factores:
#
# 1.   Pies cuadrados de la tienda
# 2.   Inventario
# 1.   Gastos en publicidad
# 2.   Tamaño del distrito (número de familias)
# 1.   Número de tiendas de la competencia en la zona
#
# Se reveló que los primero cuatro factores tienen un impacto positivo en las ventas, siendo el tamaño de la tienda el más importante ya que a mayor espacio, mayores ventas, después el tamaño del distrito, indica que ubicarse en zonas con mayor población es una estrategia acertada, y la inversión en publicidad y el nivel de inventario también muestran un efecto positivo significativo.
#
# Por el contrario, la presencia de tiendas de la competencia tiene un efecto negativo, ya que los competidores reducen las ventas esperadas.
#
# Con base en la evidencia obtenida, se concluye que es razonable adquirir más tiendas durante el próximo año, siempre que se sigan criterios basados en los datos, por ello se recomienda priorizar ubicaciones en distritos con alta población y baja presencia de competidores, así como asegurar que las nuevas tiendas tengan un tamaño adecuado desde su apertura, además de ser importante el
# destinar presupuesto suficiente para inventario y publicidad, ya que ambas inversiones están asociadas a mayores ventas.

# %% [markdown]
# ---
# ---
